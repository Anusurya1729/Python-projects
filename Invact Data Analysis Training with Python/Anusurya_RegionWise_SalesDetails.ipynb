# %% [markdown]
# # RegionWise-SalesDetails_3.1

# %% [markdown]
# ***`Task 1: Import the pandas library`***

# %%
import pandas as pd

# %% [markdown]
# ***`Task 2: Create a dataframe named “rwsd” from a given URL.`***
#
# https://raw.githubusercontent.com/Invact-Abhay/DOE/main/fe2final.csv

# %%
rwsd=pd.read_csv("https://raw.githubusercontent.com/Invact-Abhay/DOE/main/fe2final.csv")
rwsd
# Out:
#          Salesperson Region     Product  QuantitySold  UnitPrice  Sales
# 0       Aarav Kapoor  North      Phones           300         30   9000
# 1         Diya Patel  South     Laptops           150        100  15000
# 2       Ishan Sharma   East  Headphones           200         60  12000
# 3         Riya Gupta   West      Phones           250         30   7500
# 4        Kabir Singh  North     Laptops           180        100  18000
# 5          Zara Khan  South  Headphones           220         60  13200
# 6       Ananya Reddy   East      Phones           270         30   8100
# 7     Arjun Malhotra   West     Laptops           190        100  19000
# 8    Niharika Sharma  North  Headphones           310         60  18600
# 9     Vikram Chauhan  South      Phones           200         30   6000
# 10       Meera Joshi   East     Laptops           150        100  15000
# 11      Yuvraj Singh   West  Headphones           180         60  10800
# ...

# %% [markdown]
# ***`Task 3: Find the data  of the salespersons whose region is “North”.`***

# %%
rwsd.query('Region=="North"')
# Out:
#         Salesperson Region     Product  QuantitySold  UnitPrice  Sales
# 0      Aarav Kapoor  North      Phones           300         30   9000
# 4       Kabir Singh  North     Laptops           180        100  18000
# 8   Niharika Sharma  North  Headphones           310         60  18600
# 12     Aanya Khanna  North      Phones           280         30   8400
# 16       Kyra Reddy  North     Laptops           195        100  19500
# 20     Kiaan Sharma  North  Headphones           320         60  19200
# 24     Aarav Khanna  North      Phones           300         30   9000

# %% [markdown]
# ***`Task 4: Find the data of the salespersons who deal with Laptops.`***

# %%
rwsd.query('Product=="Laptops"')
# Out:
#        Salesperson Region  Product  QuantitySold  UnitPrice  Sales
# 1       Diya Patel  South  Laptops           150        100  15000
# 4      Kabir Singh  North  Laptops           180        100  18000
# 7   Arjun Malhotra   West  Laptops           190        100  19000
# 10     Meera Joshi   East  Laptops           150        100  15000
# 13     Advik Patel  South  Laptops           170        100  17000
# 16      Kyra Reddy  North  Laptops           195        100  19500
# 19    Anvi Chauhan   West  Laptops           200        100  20000
# 22      Kyra Patel   East  Laptops           160        100  16000
# 25      Diya Gupta  South  Laptops           150        100  15000

# %% [markdown]
# ***`Task 5:`***
#
# 1.Count the number of salespersons who deal with headphones.
#
# 2.Find the maximum “QuantitySold” from the salesperson of Region “South”.
#
# 3.Find the average of “UnitPrice” from the region “North”.

# %%
rwsd.query('Product=="Headphones"')["Salesperson"].count()
# Out:
# 9

# %%
rwsd.query('Region=="South"')["QuantitySold"].max()
# Out:
# 230

# %%
rwsd.query('Region=="North"')["UnitPrice"].mean()
# Out:
# 58.57142857142857

# %% [markdown]
# ***`Task 6: Find the maximum sales among salesperson whose QuantitySold is more than 150.`***

# %%
rwsd.query('QuantitySold>150')["Sales"].max()
# Out:
# 20000

# %% [markdown]
# ***`Task 7: Find the minimum sales among salesperson whose region is West.`***

# %%
rwsd.query('Region=="West"')["Sales"].min()
# Out:
# 7500

# %% [markdown]
# ***`Task 8: Find the sum of  “Sales” among all the salesperson where UnitPrice is 30.`***

# %%
rwsd.query('UnitPrice==30')["Sales"].sum()
# Out:
# 78150

# %% [markdown]
# ***`Task 9: Find the average of  “UnitPrice” among all the products.`***

# %%
rwsd["UnitPrice"].mean()
# Out:
# 62.142857142857146

# %% [markdown]
# ***`Task 10: Find the number of salespersons in the south region.`***

# %%
rwsd.query('Region=="South"')["Salesperson"].count()
# Out:
# 7

# %% [markdown]
# ***`Task 11: Find the average of  “Sales” by the salesperson whose region is East.`***

# %%
rwsd.query('Region=="East"')["Sales"].mean()
# Out:
# 11864.285714285714

# %% [markdown]
# ***`Task 12: Find the number of products where QuantitySold is 150.`***

# %%
rwsd.query('QuantitySold==150')["Product"].count()
# Out:
# 3

# %% [markdown]
# ***`Task 13: Find the sum of QuantitySold whose Sales is more than or equal to 15000`***

# %%
rwsd.query('Sales>=15000')["QuantitySold"].sum()
# Out:
# 2175

# %% [markdown]
# ***`Task 14: Find the average of QuantitySold where UnitPrice is more than or equal to 60.`***

# %%
rwsd.query('UnitPrice>=60')["QuantitySold"].mean()
# Out:
# 199.16666666666666

# %% [markdown]
# # RegionWise-SalesDetails_3.2

# %% [markdown]
# ***`Task 1: Print the first five rows of “rwsd” dataframe.`***

# %%
rwsd.head()
# Out:
#     Salesperson Region     Product  QuantitySold  UnitPrice  Sales
# 0  Aarav Kapoor  North      Phones           300         30   9000
# 1    Diya Patel  South     Laptops           150        100  15000
# 2  Ishan Sharma   East  Headphones           200         60  12000
# 3    Riya Gupta   West      Phones           250         30   7500
# 4   Kabir Singh  North     Laptops           180        100  18000

# %% [markdown]
# ***`Task 2: Retrieve all the columns of the SalesPerson who has the maximum QuantitySold. `***

# %%
rwsd.query('QuantitySold==QuantitySold.max()')
# Out:
#      Salesperson Region     Product  QuantitySold  UnitPrice  Sales
# 20  Kiaan Sharma  North  Headphones           320         60  19200

# %% [markdown]
# ***`Task 3:  Retrieve all the columns of the SalesPersons who have the minimum QuantitySold. `***

# %%
rwsd.query('QuantitySold==QuantitySold.min()')
# Out:
#     Salesperson Region  Product  QuantitySold  UnitPrice  Sales
# 1    Diya Patel  South  Laptops           150        100  15000
# 10  Meera Joshi   East  Laptops           150        100  15000
# 25   Diya Gupta  South  Laptops           150        100  15000

# %% [markdown]
# ***`Task 4:  Retrieve the name of the Regions which has the maximum UnitPrice out of all the sales.`***

# %%
rwsd.query('UnitPrice==UnitPrice.max()')["Region"]
# Out:
# 1     South
# 4     North
# 7      West
# 10     East
# 13    South
# 16    North
# 19     West
# 22     East
# 25    South
# Name: Region, dtype: object

# %% [markdown]
# ***`Task 5:  Retrieve the name of the Regions which has the minimum QuantitySold out of all the sales.`***

# %%
rwsd.query('QuantitySold==QuantitySold.min()')["Region"]
# Out:
# 1     South
# 10     East
# 25    South
# Name: Region, dtype: object

# %% [markdown]
# ***`Task 6: Retrieve the name of the Salespersons whose Sales is more than the average sales of all the products.`***

# %%
rwsd.query('Sales>Sales.mean()')["Salesperson"]
# Out:
# 1          Diya Patel
# 4         Kabir Singh
# 5           Zara Khan
# 7      Arjun Malhotra
# 8     Niharika Sharma
# 10        Meera Joshi
# 13        Advik Patel
# 16         Kyra Reddy
# 17     Aaradhya Singh
# 19       Anvi Chauhan
# 20       Kiaan Sharma
# 22         Kyra Patel
# 25         Diya Gupta
# Name: Salesperson, dtype: object

# %% [markdown]
# ***`Task 7: Retrieve the name of the Salespersons whose Sales is less than the average Sales of all the products.`***

# %%
rwsd.query('Sales<Sales.mean()')["Salesperson"]
# Out:
# 0         Aarav Kapoor
# 2         Ishan Sharma
# 3           Riya Gupta
# 6         Ananya Reddy
# 9       Vikram Chauhan
# 11        Yuvraj Singh
# 12        Aanya Khanna
# 14        Saanvi Gupta
# 15       Vihaan Sharma
# 18    Reyansh Malhotra
# 21        Aarush Joshi
# 23         Ayaan Singh
# 24        Aarav Khanna
# 26         Ishan Reddy
# 27         Riya Sharma
# Name: Salesperson, dtype: object
